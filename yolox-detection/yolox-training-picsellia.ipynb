# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import os

os.environ["PICSELLIA_SDK_CUSTOM_LOGGING"] = "True"
os.environ["PICSELLIA_SDK_DOWNLOAD_BAR_MODE"] = "2"
logging.getLogger("picsellia").setLevel(logging.INFO)
os.environ["api_token"] = "6ccfdfbfc3e1393408b684e4df5c0c89f292fe3b"
os.environ["experiment_id"] = "018cb020-2895-73bf-9cdb-471d85f2cff4"
os.environ["organization_id"] = "2856a16a-8d44-4c11-b24f-692cc2276afa"

# %%
import picsellia
from picsellia import Experiment


def get_experiment() -> Experiment:
    if "api_token" not in os.environ:
        raise Exception("You must set an api_token to run this image")
    api_token = os.environ["api_token"]

    if "host" not in os.environ:
        host = "https://app.picsellia.com"
    else:
        host = os.environ["host"]

    if "organization_id" not in os.environ:
        organization_id = None
    else:
        organization_id = os.environ["organization_id"]

    client = picsellia.Client(
        api_token=api_token, host=host, organization_id=organization_id
    )

    if "experiment_id" in os.environ:
        experiment_id = os.environ["experiment_id"]

        experiment = client.get_experiment_by_id(experiment_id)
    else:
        raise Exception(
            "You must set the experiment_id"
        )
    return experiment


experiment = get_experiment()

# %%
from pycocotools.coco import COCO
import json
from picsellia.exceptions import ResourceNotFoundError
from experiment.utils import create_yolo_detection_label

experiment.download_artifacts(with_tree=True)
current_dir = os.path.join(os.getcwd(), experiment.base_dir)
base_imgdir = experiment.png_dir

parameters = experiment.get_log(name="parameters").data
attached_datasets = experiment.list_attached_dataset_versions()

if len(attached_datasets) == 3:
    try:
        train_ds = experiment.get_dataset(name="train")
    except Exception:
        raise ResourceNotFoundError("Found 3 attached datasets, but can't find any 'train' dataset.\n \
                                            expecting 'train', 'test', ('val' or 'eval')")
    try:
        test_ds = experiment.get_dataset(name="test")
    except Exception:
        raise ResourceNotFoundError("Found 3 attached datasets, but can't find any 'test' dataset.\n \
                                            expecting 'train', 'test', ('val' or 'eval')")
    try:
        val_ds = experiment.get_dataset(name="val")
    except Exception:
        try:
            val_ds = experiment.get_dataset(name="eval")
        except Exception:
            raise ResourceNotFoundError("Found 3 attached datasets, but can't find any 'eval' dataset.\n \
                                                expecting 'train', 'test', ('val' or 'eval')")

    labels = train_ds.list_labels()
    label_names = [label.name for label in labels]
    labelmap = {str(i): label.name for i, label in enumerate(labels)}

    # for data_type, dataset in {
    #     "train": train_ds,
    #     "val": val_ds,
    #     "test": test_ds,
    # }.items():
    #     coco_annotation = dataset.build_coco_file_locally(enforced_ordered_categories=label_names)
    #     annotations_dict = coco_annotation.dict()
    #     annotations_path = os.path.join(base_imgdir, f"{data_type}_annotations.json")
    # 
    #     with open(annotations_path, 'w') as f:
    #         f.write(json.dumps(annotations_dict))
    # 
    #     annotations_coco = COCO(annotations_path)
    # 
    #     dataset.list_assets().download(
    #         target_path=os.path.join(base_imgdir, data_type, "images"), max_workers=8
    #     )

else:
    dataset = experiment.list_attached_dataset_versions()[0]
    coco_annotation = dataset.build_coco_file_locally()
    annotations_dict = coco_annotation.dict()
    annotations_path = "annotations.json"
    with open(annotations_path, 'w') as f:
        f.write(json.dumps(annotations_dict))
    annotations_coco = COCO(annotations_path)

    labels = dataset.list_labels()
    label_names = [label.name for label in labels]
    labelmap = {str(i): label.name for i, label in enumerate(labels)}

    prop = (
        0.7
        if not "prop_train_split" in parameters.keys()
        else parameters["prop_train_split"]
    )

    train_assets, test_assets, val_assets = dataset.train_test_val_split(
        ratios=[prop, (1. - prop) / 2, (1. - prop) / 2]
    )

    for data_type, assets in {
        "train": train_assets,
        "val": val_assets,
        "test": test_assets,
    }.items():
        assets.download(
            target_path=os.path.join(base_imgdir, data_type, "images"), max_workers=8
        )

        create_yolo_detection_label(
            experiment, data_type, annotations_dict, annotations_coco, label_names
        )

experiment.log("labelmap", labelmap, "labelmap", replace=True)
cwd = os.getcwd()

# %%
if os.path.isdir(f"{experiment.png_dir}/train"):
    os.rename(f"{experiment.png_dir}/train",
              f"{experiment.png_dir}/train2017")

if os.path.isdir(f"{experiment.png_dir}/test"):
    os.rename(f"{experiment.png_dir}/test",
              f"{experiment.png_dir}/test2017")

if os.path.isdir(f"{experiment.png_dir}/val"):
    os.rename(f"{experiment.png_dir}/val",
              f"{experiment.png_dir}/val2017")

# %%
parameters = experiment.get_log("parameters").data

if "architecture" not in parameters:
    raise AssertionError("The YoloX cannot be created since the model parameter \"architecture\" is missing.")

model_architecture = parameters["architecture"]
dataset_base_dir_path = experiment.base_dir
dataset_train_annotation_file_path = f"{experiment.png_dir}/train_annotations.json"
dataset_test_annotation_file_path = f"{experiment.png_dir}/test_annotations.json"
dataset_val_annotation_file_path = f"{experiment.png_dir}/val_annotations.json"
model_latest_checkpoint_path = f"{experiment.checkpoint_dir}/{model_architecture}.pth"

if not os.path.isfile(model_latest_checkpoint_path):
    model_latest_checkpoint_path = None

learning_rate = parameters.get("learning_rate", 0.01 / 64)
batch_size = parameters.get("batch_size", 8)
epochs = parameters.get("epochs", 100)
image_size = int(parameters.get("image_size", 640))

# %%
from YOLOX.tools.train import main, make_parser
from YOLOX.yolox.exp import check_exp_value
from YOLOX.yolox.utils import configure_module, get_num_devices
from YOLOX.yolox.exp.build import get_exp_by_name

# 1 - Args
configure_module()
args = make_parser().parse_args()

args.name = model_architecture

args.data_dir = experiment.png_dir
args.train_ann = dataset_train_annotation_file_path
args.test_ann = dataset_test_annotation_file_path
args.val_ann = dataset_val_annotation_file_path
args.ckpt = model_latest_checkpoint_path

args.num_classes = len(labelmap)
args.learning_rate = learning_rate
args.batch_size = batch_size
args.epochs = epochs
args.image_size = (image_size, image_size)

# 2 - Get model architecture
exp = get_exp_by_name(args)
exp.merge(args.opts)
check_exp_value(exp)

if not args.experiment_name:
    args.experiment_name = exp.exp_name

num_gpu = get_num_devices() if args.devices is None else args.devices
assert num_gpu <= get_num_devices()

# 3 - Launch training
main(exp, args)
# Out:
# 2023-12-28 16:36:16 | INFO     | YOLOX.yolox.core.trainer:129 - args: Namespace(experiment_name='yolox_s', name='yolox_s', dist_backend='nccl', dist_url=None, batch_size=4, devices=None, exp_file='/home/alexis/.local/share/jupyter/runtime/kernel-2200a8a3-1d09-4d00-b1f4-87aec3266758.json', resume=False, ckpt='test-yolox_s-1/checkpoint/yolox_s.pth', start_epoch=None, num_machines=1, machine_rank=0, fp16=False, cache=None, occupy=False, logger='tensorboard', opts=[], data_dir='test-yolox_s-1/images', train_ann='test-yolox_s-1/images/train_annotations.json', test_ann='test-yolox_s-1/images/test_annotations.json', val_ann='test-yolox_s-1/images/val_annotations.json', num_classes=3, learning_rate=0.0001, epochs=1, image_size=(640, 640))
# 2023-12-28 16:36:16 | INFO     | YOLOX.yolox.core.trainer:130 - exp value:
# ╒═══════════════════╤════════════════════════════════════════════════╕
# │ keys              │ values                                         │
# ╞═══════════════════╪════════════════════════════════════════════════╡
# │ seed              │ None                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ output_dir        │ './YOLOX_outputs'                              │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ print_interval    │ 10                                             │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ eval_interval     │ 10                                             │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ dataset           │ None                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ num_classes       │ 3                                              │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ depth             │ 0.33                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ width             │ 0.5                                            │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ act               │ 'silu'                                         │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ data_num_workers  │ 4                                              │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ input_size        │ (640, 640)                                     │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ multiscale_range  │ 5                                              │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ data_dir          │ 'test-yolox_s-1/images'                        │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ train_ann         │ 'test-yolox_s-1/images/train_annotations.json' │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ val_ann           │ 'test-yolox_s-1/images/val_annotations.json'   │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ test_ann          │ 'test-yolox_s-1/images/test_annotations.json'  │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ mosaic_prob       │ 1.0                                            │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ mixup_prob        │ 1.0                                            │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ hsv_prob          │ 1.0                                            │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ flip_prob         │ 0.5                                            │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ degrees           │ 10.0                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ translate         │ 0.1                                            │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ mosaic_scale      │ (0.1, 2)                                       │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ enable_mixup      │ True                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ mixup_scale       │ (0.5, 1.5)                                     │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ shear             │ 2.0                                            │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ warmup_epochs     │ 5                                              │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ max_epoch         │ 1                                              │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ warmup_lr         │ 0                                              │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ min_lr_ratio      │ 0.05                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ basic_lr_per_img  │ 0.0001                                         │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ scheduler         │ 'yoloxwarmcos'                                 │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ no_aug_epochs     │ 15                                             │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ ema               │ True                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ weight_decay      │ 0.0005                                         │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ momentum          │ 0.9                                            │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ save_history_ckpt │ True                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ exp_name          │ 'yolox_s'                                      │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ test_size         │ (640, 640)                                     │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ test_conf         │ 0.01                                           │
# ├───────────────────┼────────────────────────────────────────────────┤
# │ nmsthre           │ 0.65                                           │
# ╘═══════════════════╧════════════════════════════════════════════════╛
# 2023-12-28 16:36:17 | INFO     | YOLOX.yolox.core.trainer:135 - Model Summary: Params: 8.94M, Gflops: 26.76
# 2023-12-28 16:36:17 | INFO     | YOLOX.yolox.core.trainer:321 - loading checkpoint for fine tuning
# 2023-12-28 16:36:17 | WARNING  | YOLOX.yolox.utils.checkpoint:24 - Shape of head.cls_preds.0.weight in checkpoint is torch.Size([80, 128, 1, 1]), while shape of head.cls_preds.0.weight in model is torch.Size([3, 128, 1, 1]).
# 2023-12-28 16:36:17 | WARNING  | YOLOX.yolox.utils.checkpoint:24 - Shape of head.cls_preds.0.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.0.bias in model is torch.Size([3]).
# 2023-12-28 16:36:17 | WARNING  | YOLOX.yolox.utils.checkpoint:24 - Shape of head.cls_preds.1.weight in checkpoint is torch.Size([80, 128, 1, 1]), while shape of head.cls_preds.1.weight in model is torch.Size([3, 128, 1, 1]).
# 2023-12-28 16:36:17 | WARNING  | YOLOX.yolox.utils.checkpoint:24 - Shape of head.cls_preds.1.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.1.bias in model is torch.Size([3]).
# 2023-12-28 16:36:17 | WARNING  | YOLOX.yolox.utils.checkpoint:24 - Shape of head.cls_preds.2.weight in checkpoint is torch.Size([80, 128, 1, 1]), while shape of head.cls_preds.2.weight in model is torch.Size([3, 128, 1, 1]).
# 2023-12-28 16:36:17 | WARNING  | YOLOX.yolox.utils.checkpoint:24 - Shape of head.cls_preds.2.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.2.bias in model is torch.Size([3]).
# 2023-12-28 16:36:17 | INFO     | YOLOX.yolox.data.datasets.coco:63 - loading annotations into memory...
# 2023-12-28 16:36:17 | INFO     | YOLOX.yolox.data.datasets.coco:63 - Done (t=0.25s)
# 2023-12-28 16:36:17 | INFO     | pycocotools.coco:86 - creating index...
# 2023-12-28 16:36:17 | INFO     | pycocotools.coco:86 - index created!
# 2023-12-28 16:36:18 | INFO     | YOLOX.yolox.core.trainer:154 - init prefetcher, this might take one minute or less...
# 2023-12-28 16:36:19 | INFO     | YOLOX.yolox.data.datasets.coco:63 - loading annotations into memory...
# 2023-12-28 16:36:19 | INFO     | YOLOX.yolox.data.datasets.coco:63 - Done (t=0.01s)
# 2023-12-28 16:36:19 | INFO     | pycocotools.coco:86 - creating index...
# 2023-12-28 16:36:19 | INFO     | pycocotools.coco:86 - index created!
# 2023-12-28 16:36:19 | INFO     | YOLOX.yolox.core.trainer:190 - Training start...
# 2023-12-28 16:36:19 | INFO     | YOLOX.yolox.core.trainer:191 -
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode='nearest')
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )
# 2023-12-28 16:36:19 | INFO     | YOLOX.yolox.core.trainer:204 - ---> start train epoch1
# 2023-12-28 16:36:19 | INFO     | YOLOX.yolox.core.trainer:207 - --->No mosaic aug now!
# 2023-12-28 16:36:19 | INFO     | YOLOX.yolox.core.trainer:209 - --->Add additional L1 loss now!
# 2023-12-28 16:36:24 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 10/645, gpu mem: 2438Mb, mem: 7.2Gb, iter_time: 0.572s, data_time: 0.002s, total_loss: 13.1, iou_loss: 2.6, l1_loss: 0.7, conf_loss: 6.9, cls_loss: 2.9, lr: 3.846e-09, size: 640, ETA: 0:06:03
# 2023-12-28 16:36:28 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 20/645, gpu mem: 2438Mb, mem: 7.3Gb, iter_time: 0.363s, data_time: 0.002s, total_loss: 15.9, iou_loss: 2.7, l1_loss: 0.7, conf_loss: 9.0, cls_loss: 3.5, lr: 1.538e-08, size: 576, ETA: 0:04:52
# 2023-12-28 16:36:32 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 30/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.425s, data_time: 0.002s, total_loss: 18.0, iou_loss: 2.8, l1_loss: 0.8, conf_loss: 11.1, cls_loss: 3.4, lr: 3.461e-08, size: 672, ETA: 0:04:38
# 2023-12-28 16:36:34 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 40/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.166s, data_time: 0.001s, total_loss: 15.9, iou_loss: 2.9, l1_loss: 0.9, conf_loss: 9.5, cls_loss: 2.7, lr: 6.153e-08, size: 640, ETA: 0:03:50
# 2023-12-28 16:36:36 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 50/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.163s, data_time: 0.001s, total_loss: 15.4, iou_loss: 2.9, l1_loss: 0.8, conf_loss: 9.3, cls_loss: 2.4, lr: 9.615e-08, size: 640, ETA: 0:03:20
# 2023-12-28 16:36:40 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 60/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.483s, data_time: 0.002s, total_loss: 15.9, iou_loss: 3.0, l1_loss: 0.9, conf_loss: 8.5, cls_loss: 3.5, lr: 1.385e-07, size: 768, ETA: 0:03:31
# 2023-12-28 16:36:43 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 70/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.228s, data_time: 0.002s, total_loss: 12.9, iou_loss: 2.9, l1_loss: 0.8, conf_loss: 7.3, cls_loss: 1.9, lr: 1.885e-07, size: 768, ETA: 0:03:17
# 2023-12-28 16:36:46 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 80/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.368s, data_time: 0.002s, total_loss: 18.5, iou_loss: 3.6, l1_loss: 1.2, conf_loss: 11.8, cls_loss: 1.8, lr: 2.461e-07, size: 608, ETA: 0:03:15
# 2023-12-28 16:36:52 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 90/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.526s, data_time: 0.002s, total_loss: 15.3, iou_loss: 2.7, l1_loss: 0.7, conf_loss: 8.8, cls_loss: 3.1, lr: 3.115e-07, size: 800, ETA: 0:03:23
# 2023-12-28 16:36:56 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 100/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.440s, data_time: 0.002s, total_loss: 14.6, iou_loss: 2.8, l1_loss: 0.8, conf_loss: 8.0, cls_loss: 2.9, lr: 3.846e-07, size: 704, ETA: 0:03:23
# 2023-12-28 16:36:59 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 110/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.248s, data_time: 0.002s, total_loss: 15.7, iou_loss: 3.1, l1_loss: 1.3, conf_loss: 9.5, cls_loss: 1.9, lr: 4.654e-07, size: 800, ETA: 0:03:13
# 2023-12-28 16:37:00 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 120/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.157s, data_time: 0.002s, total_loss: 15.0, iou_loss: 3.0, l1_loss: 1.0, conf_loss: 8.6, cls_loss: 2.3, lr: 5.538e-07, size: 576, ETA: 0:03:01
# 2023-12-28 16:37:03 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 130/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.294s, data_time: 0.002s, total_loss: 12.1, iou_loss: 2.3, l1_loss: 0.6, conf_loss: 5.9, cls_loss: 3.3, lr: 6.500e-07, size: 480, ETA: 0:02:55
# 2023-12-28 16:37:05 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 140/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.185s, data_time: 0.002s, total_loss: 12.3, iou_loss: 2.5, l1_loss: 0.7, conf_loss: 6.8, cls_loss: 2.2, lr: 7.538e-07, size: 672, ETA: 0:02:46
# 2023-12-28 16:37:07 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 150/645, gpu mem: 3353Mb, mem: 7.3Gb, iter_time: 0.171s, data_time: 0.001s, total_loss: 15.4, iou_loss: 2.6, l1_loss: 0.9, conf_loss: 8.0, cls_loss: 3.9, lr: 8.653e-07, size: 640, ETA: 0:02:37
# 2023-12-28 16:37:09 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 160/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.246s, data_time: 0.002s, total_loss: 11.6, iou_loss: 2.1, l1_loss: 0.5, conf_loss: 6.0, cls_loss: 3.0, lr: 9.846e-07, size: 768, ETA: 0:02:32
# 2023-12-28 16:37:11 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 170/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.160s, data_time: 0.002s, total_loss: 12.1, iou_loss: 2.5, l1_loss: 0.7, conf_loss: 6.2, cls_loss: 2.7, lr: 1.111e-06, size: 608, ETA: 0:02:25
# 2023-12-28 16:37:12 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 180/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.168s, data_time: 0.002s, total_loss: 12.1, iou_loss: 2.7, l1_loss: 0.8, conf_loss: 6.4, cls_loss: 2.2, lr: 1.246e-06, size: 640, ETA: 0:02:18
# 2023-12-28 16:37:14 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 190/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.149s, data_time: 0.002s, total_loss: 11.7, iou_loss: 2.0, l1_loss: 0.7, conf_loss: 5.9, cls_loss: 3.1, lr: 1.388e-06, size: 576, ETA: 0:02:11
# 2023-12-28 16:37:16 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 200/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.250s, data_time: 0.002s, total_loss: 10.4, iou_loss: 1.6, l1_loss: 0.4, conf_loss: 5.0, cls_loss: 3.4, lr: 1.538e-06, size: 800, ETA: 0:02:08
# 2023-12-28 16:37:18 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 210/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.159s, data_time: 0.002s, total_loss: 11.5, iou_loss: 2.5, l1_loss: 0.7, conf_loss: 5.9, cls_loss: 2.5, lr: 1.696e-06, size: 608, ETA: 0:02:02
# 2023-12-28 16:37:22 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 220/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.348s, data_time: 0.002s, total_loss: 9.7, iou_loss: 2.2, l1_loss: 0.7, conf_loss: 4.9, cls_loss: 2.0, lr: 1.861e-06, size: 544, ETA: 0:02:01
# 2023-12-28 16:37:24 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 230/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.197s, data_time: 0.002s, total_loss: 10.9, iou_loss: 2.3, l1_loss: 0.6, conf_loss: 5.5, cls_loss: 2.5, lr: 2.034e-06, size: 704, ETA: 0:01:56
# 2023-12-28 16:37:25 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 240/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.154s, data_time: 0.002s, total_loss: 8.5, iou_loss: 1.4, l1_loss: 0.3, conf_loss: 4.7, cls_loss: 2.1, lr: 2.215e-06, size: 576, ETA: 0:01:51
# 2023-12-28 16:37:27 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 250/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.152s, data_time: 0.002s, total_loss: 8.1, iou_loss: 2.0, l1_loss: 0.5, conf_loss: 3.6, cls_loss: 2.0, lr: 2.404e-06, size: 576, ETA: 0:01:46
# 2023-12-28 16:37:30 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 260/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.322s, data_time: 0.002s, total_loss: 8.7, iou_loss: 1.7, l1_loss: 0.4, conf_loss: 4.3, cls_loss: 2.2, lr: 2.600e-06, size: 512, ETA: 0:01:45
# 2023-12-28 16:37:35 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 270/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.466s, data_time: 0.002s, total_loss: 8.2, iou_loss: 2.0, l1_loss: 0.6, conf_loss: 3.5, cls_loss: 2.0, lr: 2.804e-06, size: 736, ETA: 0:01:44
# 2023-12-28 16:37:36 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 280/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.153s, data_time: 0.002s, total_loss: 7.5, iou_loss: 2.0, l1_loss: 0.5, conf_loss: 3.4, cls_loss: 1.7, lr: 3.015e-06, size: 576, ETA: 0:01:40
# 2023-12-28 16:37:38 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 290/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.229s, data_time: 0.002s, total_loss: 8.4, iou_loss: 1.8, l1_loss: 0.4, conf_loss: 4.1, cls_loss: 2.1, lr: 3.234e-06, size: 768, ETA: 0:01:37
# 2023-12-28 16:37:41 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 300/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.231s, data_time: 0.002s, total_loss: 7.3, iou_loss: 2.3, l1_loss: 0.6, conf_loss: 2.8, cls_loss: 1.6, lr: 3.461e-06, size: 768, ETA: 0:01:33
# 2023-12-28 16:37:42 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 310/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.163s, data_time: 0.002s, total_loss: 6.7, iou_loss: 1.7, l1_loss: 0.4, conf_loss: 2.8, cls_loss: 1.7, lr: 3.696e-06, size: 608, ETA: 0:01:30
# 2023-12-28 16:37:45 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 320/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.222s, data_time: 0.002s, total_loss: 5.8, iou_loss: 1.4, l1_loss: 0.3, conf_loss: 1.8, cls_loss: 2.3, lr: 3.938e-06, size: 736, ETA: 0:01:26
# 2023-12-28 16:37:46 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 330/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.164s, data_time: 0.003s, total_loss: 6.8, iou_loss: 1.6, l1_loss: 0.3, conf_loss: 3.0, cls_loss: 1.9, lr: 4.188e-06, size: 608, ETA: 0:01:23
# 2023-12-28 16:37:49 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 340/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.252s, data_time: 0.002s, total_loss: 8.7, iou_loss: 2.1, l1_loss: 0.7, conf_loss: 4.0, cls_loss: 1.9, lr: 4.446e-06, size: 800, ETA: 0:01:20
# 2023-12-28 16:37:50 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 350/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.130s, data_time: 0.003s, total_loss: 7.9, iou_loss: 2.0, l1_loss: 0.4, conf_loss: 3.9, cls_loss: 1.6, lr: 4.711e-06, size: 512, ETA: 0:01:16
# 2023-12-28 16:37:52 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 360/645, gpu mem: 3353Mb, mem: 7.4Gb, iter_time: 0.187s, data_time: 0.002s, total_loss: 6.8, iou_loss: 1.6, l1_loss: 0.4, conf_loss: 3.1, cls_loss: 1.8, lr: 4.984e-06, size: 672, ETA: 0:01:13
# 2023-12-28 16:37:54 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 370/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.221s, data_time: 0.002s, total_loss: 6.2, iou_loss: 1.6, l1_loss: 0.3, conf_loss: 2.4, cls_loss: 1.9, lr: 5.265e-06, size: 736, ETA: 0:01:10
# 2023-12-28 16:37:56 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 380/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.170s, data_time: 0.001s, total_loss: 7.1, iou_loss: 2.5, l1_loss: 0.6, conf_loss: 2.6, cls_loss: 1.6, lr: 5.554e-06, size: 640, ETA: 0:01:07
# 2023-12-28 16:37:57 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 390/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.126s, data_time: 0.002s, total_loss: 6.6, iou_loss: 2.1, l1_loss: 0.5, conf_loss: 2.2, cls_loss: 1.8, lr: 5.850e-06, size: 512, ETA: 0:01:04
# 2023-12-28 16:37:59 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 400/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.169s, data_time: 0.001s, total_loss: 4.4, iou_loss: 1.4, l1_loss: 0.3, conf_loss: 1.3, cls_loss: 1.4, lr: 6.153e-06, size: 640, ETA: 0:01:01
# 2023-12-28 16:38:01 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 410/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.249s, data_time: 0.002s, total_loss: 5.9, iou_loss: 1.7, l1_loss: 0.3, conf_loss: 2.1, cls_loss: 1.7, lr: 6.465e-06, size: 800, ETA: 0:00:58
# 2023-12-28 16:38:04 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 420/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.221s, data_time: 0.002s, total_loss: 5.3, iou_loss: 1.7, l1_loss: 0.4, conf_loss: 1.9, cls_loss: 1.4, lr: 6.784e-06, size: 736, ETA: 0:00:55
# 2023-12-28 16:38:05 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 430/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.119s, data_time: 0.002s, total_loss: 7.6, iou_loss: 2.3, l1_loss: 0.7, conf_loss: 3.1, cls_loss: 1.4, lr: 7.111e-06, size: 480, ETA: 0:00:52
# 2023-12-28 16:38:06 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 440/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.164s, data_time: 0.001s, total_loss: 4.5, iou_loss: 1.3, l1_loss: 0.3, conf_loss: 1.8, cls_loss: 1.0, lr: 7.446e-06, size: 640, ETA: 0:00:49
# 2023-12-28 16:38:09 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 450/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.219s, data_time: 0.002s, total_loss: 6.5, iou_loss: 1.9, l1_loss: 0.5, conf_loss: 2.2, cls_loss: 1.9, lr: 7.788e-06, size: 736, ETA: 0:00:47
# 2023-12-28 16:38:11 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 460/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.186s, data_time: 0.002s, total_loss: 5.8, iou_loss: 1.3, l1_loss: 0.3, conf_loss: 2.2, cls_loss: 2.0, lr: 8.138e-06, size: 672, ETA: 0:00:44
# 2023-12-28 16:38:12 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 470/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.125s, data_time: 0.002s, total_loss: 6.6, iou_loss: 1.8, l1_loss: 0.4, conf_loss: 3.0, cls_loss: 1.5, lr: 8.496e-06, size: 512, ETA: 0:00:41
# 2023-12-28 16:38:13 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 480/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.152s, data_time: 0.002s, total_loss: 5.3, iou_loss: 2.0, l1_loss: 0.5, conf_loss: 1.7, cls_loss: 1.1, lr: 8.861e-06, size: 576, ETA: 0:00:39
# 2023-12-28 16:38:15 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 490/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.140s, data_time: 0.002s, total_loss: 4.8, iou_loss: 1.6, l1_loss: 0.3, conf_loss: 1.7, cls_loss: 1.2, lr: 9.234e-06, size: 544, ETA: 0:00:36
# 2023-12-28 16:38:16 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 500/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.121s, data_time: 0.002s, total_loss: 5.0, iou_loss: 1.5, l1_loss: 0.3, conf_loss: 1.6, cls_loss: 1.6, lr: 9.615e-06, size: 480, ETA: 0:00:33
# 2023-12-28 16:38:18 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 510/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.233s, data_time: 0.002s, total_loss: 6.1, iou_loss: 1.9, l1_loss: 0.5, conf_loss: 2.2, cls_loss: 1.4, lr: 1.000e-05, size: 768, ETA: 0:00:31
# 2023-12-28 16:38:20 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 520/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.142s, data_time: 0.002s, total_loss: 6.1, iou_loss: 2.1, l1_loss: 0.5, conf_loss: 2.1, cls_loss: 1.3, lr: 1.040e-05, size: 544, ETA: 0:00:28
# 2023-12-28 16:38:22 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 530/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.200s, data_time: 0.002s, total_loss: 4.6, iou_loss: 1.5, l1_loss: 0.3, conf_loss: 1.4, cls_loss: 1.3, lr: 1.080e-05, size: 704, ETA: 0:00:26
# 2023-12-28 16:38:23 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 540/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.153s, data_time: 0.002s, total_loss: 5.8, iou_loss: 1.9, l1_loss: 0.4, conf_loss: 2.1, cls_loss: 1.4, lr: 1.121e-05, size: 576, ETA: 0:00:24
# 2023-12-28 16:38:25 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 550/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.124s, data_time: 0.002s, total_loss: 6.4, iou_loss: 1.9, l1_loss: 0.4, conf_loss: 2.4, cls_loss: 1.6, lr: 1.163e-05, size: 512, ETA: 0:00:21
# 2023-12-28 16:38:26 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 560/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.139s, data_time: 0.002s, total_loss: 6.1, iou_loss: 2.1, l1_loss: 0.4, conf_loss: 1.6, cls_loss: 2.1, lr: 1.206e-05, size: 544, ETA: 0:00:19
# 2023-12-28 16:38:27 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 570/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.141s, data_time: 0.002s, total_loss: 5.4, iou_loss: 1.9, l1_loss: 0.4, conf_loss: 1.7, cls_loss: 1.4, lr: 1.250e-05, size: 544, ETA: 0:00:16
# 2023-12-28 16:38:29 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 580/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.122s, data_time: 0.002s, total_loss: 5.3, iou_loss: 1.9, l1_loss: 0.4, conf_loss: 1.6, cls_loss: 1.4, lr: 1.294e-05, size: 480, ETA: 0:00:14
# 2023-12-28 16:38:30 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 590/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.161s, data_time: 0.002s, total_loss: 5.8, iou_loss: 1.9, l1_loss: 0.6, conf_loss: 2.1, cls_loss: 1.2, lr: 1.339e-05, size: 608, ETA: 0:00:12
# 2023-12-28 16:38:33 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 600/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.251s, data_time: 0.002s, total_loss: 4.9, iou_loss: 1.4, l1_loss: 0.3, conf_loss: 1.7, cls_loss: 1.5, lr: 1.385e-05, size: 800, ETA: 0:00:10
# 2023-12-28 16:38:35 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 610/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.200s, data_time: 0.002s, total_loss: 4.3, iou_loss: 1.6, l1_loss: 0.3, conf_loss: 1.3, cls_loss: 1.1, lr: 1.431e-05, size: 704, ETA: 0:00:07
# 2023-12-28 16:38:37 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 620/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.231s, data_time: 0.002s, total_loss: 4.4, iou_loss: 1.5, l1_loss: 0.4, conf_loss: 1.4, cls_loss: 1.0, lr: 1.478e-05, size: 768, ETA: 0:00:05
# 2023-12-28 16:38:39 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 630/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.170s, data_time: 0.002s, total_loss: 4.5, iou_loss: 1.4, l1_loss: 0.3, conf_loss: 1.7, cls_loss: 1.1, lr: 1.526e-05, size: 640, ETA: 0:00:03
# 2023-12-28 16:38:40 | INFO     | YOLOX.yolox.core.trainer:257 - epoch: 1/1, iter: 640/645, gpu mem: 3353Mb, mem: 7.5Gb, iter_time: 0.119s, data_time: 0.003s, total_loss: 4.9, iou_loss: 1.9, l1_loss: 0.4, conf_loss: 1.2, cls_loss: 1.4, lr: 1.575e-05, size: 480, ETA: 0:00:01
# 2023-12-28 16:38:41 | INFO     | YOLOX.yolox.core.trainer:368 - Save weights to ./YOLOX_outputs/yolox_s
#  98%|#########7| 79/81 [00:04<00:00, 17.03it/s]
# 2023-12-28 16:38:47 | INFO     | YOLOX.yolox.evaluators.coco_evaluator:282 - Evaluate in main process...
# 100%|##########| 81/81 [00:05<00:00, 13.99it/s]
# 2023-12-28 16:38:47 | INFO     | YOLOX.yolox.evaluators.coco_evaluator:315 - Loading and preparing results...
# 2023-12-28 16:38:47 | INFO     | YOLOX.yolox.evaluators.coco_evaluator:315 - DONE (t=0.07s)
# 2023-12-28 16:38:47 | INFO     | pycocotools.coco:366 - creating index...
# 2023-12-28 16:38:47 | INFO     | pycocotools.coco:366 - index created!
# 2023-12-28 16:38:48 | INFO     | YOLOX.yolox.layers.jit_ops:119 - Load fast_cocoeval op in 0.405s.
# /home/alexis/Documents/Projects/picsellia-training-engine/yolox-detection/YOLOX/yolox/evaluators/coco_evaluator.py:210: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   statistics = torch.cuda.FloatTensor([inference_time, nms_time, n_samples])
# Using /home/alexis/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Emitting ninja build file /home/alexis/.cache/torch_extensions/py310_cu121/fast_cocoeval/build.ninja...
# Building extension module fast_cocoeval...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# 2023-12-28 16:38:48 | INFO     | YOLOX.yolox.core.trainer:358 -
# Average forward time: 9.80 ms, Average NMS time: 1.46 ms, Average inference time: 11.25 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.582
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.575
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.610
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.714
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# per class AP:
# | class        | AP     | class      | AP     | class   | AP     |
# |:-------------|:-------|:-----------|:-------|:--------|:-------|
# | missing_hole | 40.564 | mouse_bite | 29.975 | short   | 45.325 |
# per class AR:
# | class        | AR     | class      | AR     | class   | AR     |
# |:-------------|:-------|:-----------|:-------|:--------|:-------|
# | missing_hole | 54.021 | mouse_bite | 58.468 | short   | 71.073 |
#
# 2023-12-28 16:38:48 | INFO     | YOLOX.yolox.core.trainer:368 - Save weights to ./YOLOX_outputs/yolox_s
# 2023-12-28 16:38:49 | INFO     | YOLOX.yolox.core.trainer:368 - Save weights to ./YOLOX_outputs/yolox_s
# 2023-12-28 16:38:49 | INFO     | YOLOX.yolox.core.trainer:194 - Training of experiment is done and the best AP is 38.62

# %%
training_pipeline = YoloxDetectionTrainer()
training_pipeline.prepare_data_for_training()

training_pipeline.train()
training_pipeline.eval()
